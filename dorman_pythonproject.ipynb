# %%
#!pip install pandas==1.3.3
#!pip install requests==2.26.0
# !mamba install bs4==4.10.0 -y
# !mamba install html5lib==1.1 -y
# !pip install lxml==4.6.4
#!pip install plotly==5.3.1
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['bs4==4.10.0']
#
# ...

# %%
# !pip install yfinance==0.1.67
#!pip install pandas==1.3.3

# %%
tesla = yfinance.Ticker("TESLA")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_658/2389868227.py in <module>
# ----> 1 tesla = yfinance.Ticker("TESLA")
#
# NameError: name 'yfinance' is not defined

# %%
import yfinance as yf
import pandas as pd

# %%
tesla = yf.Ticker("TSLA")

# %%
tesla_info=tesla.info
tesla_info
# Out:
# {'zip': '78725',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 99290,
# ...

# %%
tesla = yf.Ticker("TSLA")

# %%
tesla_data = tesla.history(period="max")

# %%
tesla_data.head()
# Out:
#                 Open      High       Low     Close     Volume  Dividends  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667  281494500          0
# 2010-06-30  1.719333  2.028000  1.553333  1.588667  257806500          0
# 2010-07-01  1.666667  1.728000  1.351333  1.464000  123282000          0
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   77097000          0
# 2010-07-06  1.333333  1.333333  1.055333  1.074000  103003500          0
#
#             Stock Splits
# Date
# 2010-06-29           0.0
# 2010-06-30           0.0
# 2010-07-01           0.0
# 2010-07-02           0.0
# 2010-07-06           0.0

# %%
tesla_data.tail()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2022-12-05  189.440002  191.270004  180.550003  182.449997  93122700
# 2022-12-06  181.220001  183.649994  175.330002  179.820007  92150800
# 2022-12-07  175.029999  179.380005  172.220001  174.039993  84213300
# 2022-12-08  172.199997  175.199997  169.059998  173.440002  97624500
# 2022-12-09  173.839996  182.500000  173.360001  181.000000  90091231
#
#             Dividends  Stock Splits
# Date
# 2022-12-05          0           0.0
# 2022-12-06          0           0.0
# 2022-12-07          0           0.0
# 2022-12-08          0           0.0
# 2022-12-09          0           0.0

# %%
tesla_revenue = tesla.totalRevenue(period="max")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_658/1313083868.py in <module>
# ----> 1 tesla_revenue = tesla.totalRevenue(period="max")
#
# AttributeError: 'Ticker' object has no attribute 'totalRevenue'

# %%
import yfinance as yf

tickers = ['TSLA']
for ticker in tickers:
    ticker_yahoo = yf.Ticker(ticker)
    data = ticker_yahoo.history()
    print(ticker)
# Out:
# TSLA

# %%
tickers = ['TSLA']
for ticker in tickers:
    ticker_yahoo = yf.Ticker(ticker)
    data = ticker_yahoo.history()
    last_quote = data['Close'].iloc[-1]
    print(ticker, data)
# Out:
# TSLA                   Open        High         Low       Close     Volume  \
# Date
# 2022-11-09  190.779999  195.889999  177.119995  177.589996  127062700
# 2022-11-10  189.899994  191.000000  180.029999  190.720001  132703000
# 2022-11-11  186.000000  196.520004  182.589996  195.970001  114403600
# 2022-11-14  192.770004  195.729996  186.339996  190.949997   92226600
# 2022-11-15  195.880005  200.820007  192.059998  194.419998   91293800
# 2022-11-16  191.509995  192.570007  185.660004  186.919998   66567600
# 2022-11-17  183.960007  186.160004  180.899994  183.169998   64336000
# 2022-11-18  185.050003  185.190002  176.550003  180.190002   76048900
# 2022-11-21  175.850006  176.770004  167.539993  167.869995   92882700
# 2022-11-22  168.630005  170.919998  166.190002  169.910004   78452300
# 2022-11-23  173.570007  183.619995  172.500000  183.199997  109536700
# 2022-11-25  185.059998  185.199997  180.630005  182.860001   50672700
# ...

# %%
gamestop = yf.Ticker("gme")

# %%
gme_data = 
gme_share_price_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_658/3461852133.py in <module>
# ----> 1 gme_share_price_data.head()
#
# NameError: name 'gme_share_price_data' is not defined

# %%
gme_data = gamestop.history(period="max")

# %%
gme_data.head()
# Out:
#                 Open      High       Low     Close    Volume  Dividends  \
# Date
# 2002-02-13  1.620128  1.693350  1.603296  1.691666  76216000        0.0
# 2002-02-14  1.712707  1.716074  1.670626  1.683250  11021600        0.0
# 2002-02-15  1.683251  1.687459  1.658002  1.674834   8389600        0.0
# 2002-02-19  1.666418  1.666418  1.578047  1.607504   7410400        0.0
# 2002-02-20  1.615920  1.662210  1.603296  1.662210   6892800        0.0
#
#             Stock Splits
# Date
# 2002-02-13           0.0
# 2002-02-14           0.0
# 2002-02-15           0.0
# 2002-02-19           0.0
# 2002-02-20           0.0

# %%
gme_data.tail
# Out:
# <bound method NDFrame.tail of                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2002-02-13   1.620128   1.693350   1.603296   1.691666  76216000        0.0
# 2002-02-14   1.712707   1.716074   1.670626   1.683250  11021600        0.0
# 2002-02-15   1.683251   1.687459   1.658002   1.674834   8389600        0.0
# 2002-02-19   1.666418   1.666418   1.578047   1.607504   7410400        0.0
# 2002-02-20   1.615920   1.662210   1.603296   1.662210   6892800        0.0
# ...               ...        ...        ...        ...       ...        ...
# 2022-12-05  27.309999  27.480000  25.440001  25.559999   4973700        0.0
# 2022-12-06  25.410000  25.580000  23.110001  23.389999   7699300        0.0
# 2022-12-07  23.400000  23.610001  21.969999  22.260000  10078200        0.0
# 2022-12-08  22.000000  25.000000  21.969999  24.790001  10252000        0.0
# 2022-12-09  24.590000  24.580000  22.820000  22.990000   4037093        0.0
#
# ...

# %%
gme_revenue.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_658/1078934641.py in <module>
# ----> 1 gme_revenue.head()
#
# NameError: name 'gme_revenue' is not defined

# %%
gme_revenue = gamestop.totalRevenue
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_658/3246167517.py in <module>
# ----> 1 gme_revenue = gamestop.totalRevenue
#
# AttributeError: 'Ticker' object has no attribute 'totalRevenue'

# %%
gme_revenue = gamestop.Revenue
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_658/1462053198.py in <module>
# ----> 1 gme_revenue = gamestop.Revenue
#
# AttributeError: 'Ticker' object has no attribute 'Revenue'

# %%
gme_revenue = gamestop.info

# %%
gme_revenue.head
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_658/4174287075.py in <module>
# ----> 1 gme_revenue.head
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
ake_graph(tesla_data, tesla_revenue, 'Tesla')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_658/814564129.py in <module>
# ----> 1 ake_graph(tesla_data, tesla_revenue, 'Tesla')
#
# NameError: name 'ake_graph' is not defined

# %%
make_graph(tesla_data, tesla_revenue, 'Tesla')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_658/851608974.py in <module>
# ----> 1 make_graph(tesla_data, tesla_revenue, 'Tesla')
#
# NameError: name 'make_graph' is not defined

# %%
import make_graph
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_658/3235310728.py in <module>
# ----> 1 import make_graph
#
# ModuleNotFoundError: No module named 'make_graph'

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
make_graph(tesla_data, tesla_revenue, 'TSlA')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_658/3262651851.py in <module>
# ----> 1 make_graph(tesla_data, tesla_revenue, 'TSlA')
#
# /tmp/ipykernel_658/1276540637.py in make_graph(stock_data, revenue_data, stock)
#       1 def make_graph(stock_data, revenue_data, stock):
#       2     fig = make_subplots(rows=2, cols=1, shared_xaxes=True, subplot_titles=("Historical Share Price", "Historical Revenue"), vertical_spacing = .3)
# ----> 3     fig.add_trace(go.Scatter(x=pd.to_datetime(stock_data.Date, infer_datetime_format=True), y=stock_data.Close.astype("float"), name="Share Price"), row=1, col=1)
#       4     fig.add_trace(go.Scatter(x=pd.to_datetime(revenue_data.Date, infer_datetime_format=True), y=revenue_data.Revenue.astype("float"), name="Revenue"), row=2, col=1)
#       5     fig.update_xaxes(title_text="Date", row=1, col=1)
#
# ...

# %%
def make_graph(stock_data, revenue_data, stock):
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, subplot_titles=("Historical Share Price", "Historical Revenue"), vertical_spacing = .3)
    fig.add_trace(go.Scatter(x=pd.to_datetime(stock_data.Date, infer_datetime_format=True), y=stock_data.Close.astype("float"), name="Share Price"), row=1, col=1)
    fig.add_trace(go.Scatter(x=pd.to_datetime(revenue_data.Date, infer_datetime_format=True), y=revenue_data.Revenue.astype("float"), name="Revenue"), row=2, col=1)
    fig.update_xaxes(title_text="Date", row=1, col=1)
    fig.update_xaxes(title_text="Date", row=2, col=1)
    fig.update_yaxes(title_text="Price ($US)", row=1, col=1)
    fig.update_yaxes(title_text="Revenue ($US Millions)", row=2, col=1)
    fig.update_layout(showlegend=False,
    height=900,
    title=stock,
    xaxis_rangeslider_visible=True)
    fig.show()

# %%
from bs4 import BeautifulSoup

# %%
import soup = BeautifulSoup(html_data, "html.parser")
soup.find_all('title')
tesla_revenue = pd.DataFrame(columns = ['Date', 'Revenue'])

for row in soup.find_all("tbody")[1].find_all("tr"):
    col = row.find_all("td")
    date = col[0].text
    revenue = col[1].text.replace("$", "").replace(",", "")
    
    tesla_revenue = tesla_revenue.append({"Date": date, "Revenue": revenue}, ignore_index = True)
# Out:
#   File "/tmp/ipykernel_658/2620691477.py", line 1
#     import soup = BeautifulSoup(html_data, "html.parser")
#                 ^
# SyntaxError: invalid syntax

# %%
make_graph(tesla_data, tesla_revenue, 'TSLA')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_658/547943050.py in <module>
# ----> 1 make_graph(tesla_data, tesla_revenue, 'TSLA')
#
# /tmp/ipykernel_658/1276540637.py in make_graph(stock_data, revenue_data, stock)
#       1 def make_graph(stock_data, revenue_data, stock):
#       2     fig = make_subplots(rows=2, cols=1, shared_xaxes=True, subplot_titles=("Historical Share Price", "Historical Revenue"), vertical_spacing = .3)
# ----> 3     fig.add_trace(go.Scatter(x=pd.to_datetime(stock_data.Date, infer_datetime_format=True), y=stock_data.Close.astype("float"), name="Share Price"), row=1, col=1)
#       4     fig.add_trace(go.Scatter(x=pd.to_datetime(revenue_data.Date, infer_datetime_format=True), y=revenue_data.Revenue.astype("float"), name="Revenue"), row=2, col=1)
#       5     fig.update_xaxes(title_text="Date", row=1, col=1)
#
# ...

# %%
make_graph(gme_data, gme_revenue, 'GameStop')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_658/2000178444.py in <module>
# ----> 1 make_graph(gme_data, gme_revenue, 'GameStop')
#
# /tmp/ipykernel_658/1276540637.py in make_graph(stock_data, revenue_data, stock)
#       1 def make_graph(stock_data, revenue_data, stock):
#       2     fig = make_subplots(rows=2, cols=1, shared_xaxes=True, subplot_titles=("Historical Share Price", "Historical Revenue"), vertical_spacing = .3)
# ----> 3     fig.add_trace(go.Scatter(x=pd.to_datetime(stock_data.Date, infer_datetime_format=True), y=stock_data.Close.astype("float"), name="Share Price"), row=1, col=1)
#       4     fig.add_trace(go.Scatter(x=pd.to_datetime(revenue_data.Date, infer_datetime_format=True), y=revenue_data.Revenue.astype("float"), name="Revenue"), row=2, col=1)
#       5     fig.update_xaxes(title_text="Date", row=1, col=1)
#
# ...
